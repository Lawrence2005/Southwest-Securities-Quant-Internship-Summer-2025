# %%
import pandas as pd
import numpy as np
import random
import copy

from scipy.stats import spearmanr, pearsonr

from collections import deque

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from typing import Optional

# %%
ENTIRE_DF = pd.read_csv('dataset.csv')

FEATURES = ["return", "turnoverrate"]  #"open", "close", "high", "low", "volume", "amount"

OPERATIONS = ["add", "sub", "mul", "div", "rolling_mean", "rolling_std", "cum_ret"]

def add(a: pd.Series, b: pd.Series):
    return a + b

def sub(a: pd.Series, b: pd.Series):
    return a - b

def mul(a: pd.Series, b: pd.Series):
    return a * b

def div(a: pd.Series, b: pd.Series):
    return np.divide(a, b, out=np.full_like(a, np.nan, dtype=float), where=b!=0)

def by_stock(x: pd.Series, df: pd.DataFrame, func):
    result = np.empty_like(x)
    for stock, idx in df.groupby("stockid").groups.items():
        series = x.loc[idx].ffill().fillna(0)
        result[idx] = func(series)
    return result

def rolling_mean(x: pd.Series, df: pd.DataFrame, w=20):
    return by_stock(x, df, lambda g: g.rolling(w).mean())

def rolling_std(x: pd.Series, df, w=20):
    return by_stock(x, df, lambda g: g.rolling(w).std(ddof=1))

def cum_ret(x: pd.Series, df, w=20):
    return by_stock(x, df, lambda g: (1 + g.fillna(0)).rolling(w).apply(np.prod, raw=True)) - 1

# %%
def winsorize_series(s, lower_q=0.01, upper_q=0.99):
    if s.isna().all():
        return s

    low = s.quantile(lower_q)
    high = s.quantile(upper_q)
    return s.clip(lower=low, upper=high)

class AlphaNode:
    NAMESPACE = {
        "add": add,
        "sub": sub,
        "mul": mul,
        "div": div,
        "rolling_mean": rolling_mean,
        "rolling_std": rolling_std,
        "cum_ret": cum_ret,
    }

    def __init__(self, val: str, left_child: Optional['AlphaNode'], right_child: Optional['AlphaNode'], param=None):
        self.val = val
        self.left = left_child
        self.right = right_child
        self.param = param

    def get_formula(self):
        if self.val in FEATURES:  # feature (leaf)
            return f"df['{self.val}']"

        elif self.val in ["rolling_mean", "rolling_std", "cum_ret"]:
            left = self.left.get_formula()
            w = self.param if self.param else 20
            return f"{self.val}({left}, df, {w})"
    
        elif self.val in self.NAMESPACE:  # binary ops
            left, right = self.left.get_formula(), self.right.get_formula()
            return f"{self.val}({left}, {right})"

        else:
            raise ValueError(f"Unknown operation {self.val}")
    
    def evaluate(self, df: pd.DataFrame):
        formula = self.get_formula()
        namespace = dict(self.NAMESPACE)
        namespace['df'] = df
        result = eval(formula, namespace)

        result = winsorize_series(pd.Series(result))

        return result.values
    
    def get_height(self):
        if not self.left and not self.right:
            return 1
        
        return 1 + max(self.left.get_height() if self.left else 0, self.right.get_height() if self.right else 0)

# %%
def calculate_IC(df: pd.DataFrame, indicators: list[str]):
    grouped = df.groupby("date", sort=False)

    ic_pearson = {}
    ic_spearman = {}
    for i in indicators:
        pearsons, spearmans = [], []
        
        for _, g in grouped:
            data = g[[i, "return"]].dropna()
            x = winsorize_series(data[i])
            y = data["return"].shift(-1)
            x, y = x[~y.isna()], y[~y.isna()]

            if len(data) < 5 or x.std(ddof=0) == 0 or y.std(ddof=0) == 0:
                pearsons.append(np.nan)
                spearmans.append(np.nan)
                continue

            pearson_corr = np.corrcoef(x, y)[0, 1]
            pearsons.append(pearson_corr)

            spearman_corr, _ = spearmanr(x, y)
            spearmans.append(spearman_corr)

        ic_pearson[i], ic_spearman[i] = pearsons, spearmans

    dates = df["date"].drop_duplicates().reset_index(drop=True)

    ic_pearson_df = pd.DataFrame(ic_pearson, index=dates).astype("float32").round(4)
    ic_spearman_df = pd.DataFrame(ic_spearman, index=dates).astype("float32").round(4)

    cum_ic_pearson_df = ic_pearson_df.cumsum().round(4)
    cum_ic_spearman_df = ic_spearman_df.cumsum().round(4)

    ic_pearson_df.to_csv("ic_pearson.csv")
    ic_spearman_df.to_csv("ic_spearman.csv")
    cum_ic_pearson_df.to_csv("cum_ic_pearson.csv")
    cum_ic_spearman_df.to_csv("cum_ic_spearman.csv")

    return ic_pearson_df, ic_spearman_df, cum_ic_pearson_df, cum_ic_spearman_df

# %%
def random_alpha_tree(max_depth=3, leaf_threshold = 0.2):
    if max_depth == 0 or (max_depth > 1 and random.random() < leaf_threshold):
        return AlphaNode(random.choice(FEATURES), None, None)
    
    func = random.choice(OPERATIONS)
    
    if func in ["rolling_mean", "rolling_std", "cum_ret", "rank"]:
        left = random_alpha_tree(max_depth-1)
        return AlphaNode(func, left, None, param=random.choice([10,20,60, 80]))
    else:
        left, right = random_alpha_tree(max_depth-1), random_alpha_tree(max_depth-1)
        return AlphaNode(func, left, right)

def mutate(node: AlphaNode, mutation_rate=0.2, max_depth=3):
    if max_depth <= 0:
        return node

    if random.random() < mutation_rate:
        return random_alpha_tree(max_depth)

    if node.left:
        node.left = mutate(node.left, mutation_rate, max_depth-1)
    if node.right:
        node.right = mutate(node.right, mutation_rate, max_depth-1)
    
    return node

def crossover(p1: AlphaNode, p2: AlphaNode):
    depth1, depth2 = random.randint(0, p1.get_height() - 1), random.randint(0, p2.get_height() - 1)

    if depth1 == 0:
        return p2

    def get_level_nodes(root: AlphaNode, l: int):
        if not root:
            return []
        
        nodes = []
        queue = deque([(root, None, 0)])

        while queue:
            curr, parent, depth = queue.popleft()

            if depth == l:
                nodes.append((curr, parent))
            elif depth < l:
                if curr.left:
                    queue.append((curr.left, curr, depth + 1))
                if curr.right:
                    queue.append((curr.right, curr, depth + 1))

        return nodes

    p1_subtree, p1_parent = random.choice(get_level_nodes(p1, depth1))
    p2_subtree, _ = random.choice(get_level_nodes(p2, depth2))

    if p1_parent.left is p1_subtree:
        p1_parent.left = copy.deepcopy(p2_subtree)
    else:
        p1_parent.right = copy.deepcopy(p2_subtree)

    return p1
    

def fitness(alpha: AlphaNode, df: pd.DataFrame):
    try:
        df["_factor"] = alpha.evaluate(df)
        if df["_factor"].isna().all():
            print(alpha.get_formula())
        
        ic_pearson_df, ic_spearman_df, _, _ = calculate_IC(df, indicators=["_factor"])
        
        mean_icp, std_icp = ic_pearson_df["_factor"].mean(skipna=True), ic_pearson_df["_factor"].std(skipna=True, ddof=0)
        mean_ics, std_ics = ic_spearman_df["_factor"].mean(skipna=True), ic_spearman_df["_factor"].std(skipna=True, ddof=0)
        
        if std_icp == 0 or std_ics == 0:
            return (-np.inf, 0)
        
        score = 0.3 * abs(mean_icp) + 0.6 * abs(mean_ics) + 0.05 * abs(mean_icp / std_icp) + 0.05* abs(mean_ics / std_ics)
        return (score, mean_ics) if not np.isnan(score) else (-np.inf, 0)
    
    except Exception:
        return (-np.inf, 0)

def evolve(population: list[AlphaNode], df: pd.DataFrame, generations=10, retain=0.3, mutation_rate=0.3):
    for g in range(generations):
        scored = [(fitness(alpha, df), alpha) for alpha in population]
        scored.sort(reverse=True, key=lambda x: x[0][0])
        print(scored)
        print(f"Gen {g}: Best fitness = {scored[0][0][0]:.4f}, Spearman IC = {scored[0][0][1]:.4f}")
        
        retain_length = int(len(scored) * retain)
        survivors = [alpha for _, alpha in scored[:retain_length]]
        
        # Generate offspring via crossover + mutation
        offspring = []
        while len(offspring) < len(population) - retain_length:
            if random.random() < 0.5 and len(survivors) >= 2:
                p1, p2 = random.sample(survivors, 2)
                child = crossover(copy.deepcopy(p1), copy.deepcopy(p2))  
            else:
                p = random.choice(survivors)
                child = mutate(copy.deepcopy(p), mutation_rate)
                
            offspring.append(child)
        
        population = survivors + offspring
    
    return population

# %%
population = [random_alpha_tree() for _ in range(15)]

evolved_population = evolve(population, ENTIRE_DF, generations=10, retain=0.3, mutation_rate=0.3)

final_scores = [(fitness(alpha, ENTIRE_DF), alpha) for alpha in evolved_population]
# Out:
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.06198071), np.float32(0.021872489)), <__main__.AlphaNode object at 0xf6ed4e911be0>), ((np.float32(0.032042444), np.float32(-0.003809723)), <__main__.AlphaNode object at 0xf6ed4e913290>), ((np.float32(0.020082379), np.float32(0.0010177868)), <__main__.AlphaNode object at 0xf6ee01ebb9e0>), ((np.float32(0.019776363), np.float32(-0.0011865877)), <__main__.AlphaNode object at 0xf6ed4e913a40>), ((np.float32(0.01844914), np.float32(0.0061800703)), <__main__.AlphaNode object at 0xf6ed4e913080>), ((np.float32(0.0039117844), np.float32(0.0008891201)), <__main__.AlphaNode object at 0xf6ee01e64470>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ed4e912300>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ed4e912390>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ed4e911b80>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ed4e913dd0>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ee01eb8260>)]
# Gen 0: Best fitness = 0.1464, Spearman IC = 0.0499
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01ecbf80>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfd3d02c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e912060>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9116d0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01f619d0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e911550>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e911100>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9102c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e912e40>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ed4e913b60>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ed4e9114f0>)]
# Gen 1: Best fitness = 0.1464, Spearman IC = 0.0499
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67140>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65ca0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e674d0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e66660>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edff0bd1c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edff0bcf20>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edff0bcef0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edff0bcd10>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edff0bd0a0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edff0bcfb0>), ((-inf, 0), <__main__.AlphaNode object at 0xf6edff0bcfe0>)]
# Gen 2: Best fitness = 0.1464, Spearman IC = 0.0499
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee02445c10>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09e720>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09f680>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09eab0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09f1a0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09fa40>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09f3e0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e66750>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65fa0>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ed4e09f710>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ed4e09ed50>)]
# Gen 3: Best fitness = 0.1464, Spearman IC = 0.0499
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee0258ed20>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09dcd0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09dca0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09d460>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09d400>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09d3a0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09d2e0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e09d250>), ((np.float32(0.019606173), np.float32(8.906122e-05)), <__main__.AlphaNode object at 0xf6ed4e09da90>), ((np.float32(0.015256219), np.float32(-0.0015116162)), <__main__.AlphaNode object at 0xf6ee020666f0>), ((np.float32(0.007314709), np.float32(-0.002247062)), <__main__.AlphaNode object at 0xf6ed4e09d520>)]
# Gen 4: Best fitness = 0.1464, Spearman IC = 0.0499
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65760>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67aa0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e66b10>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e676e0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67650>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e673b0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65400>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e66480>), ((np.float32(0.027199863), np.float32(0.0039955205)), <__main__.AlphaNode object at 0xf6ee01e669f0>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ee021a6240>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ee01e663f0>)]
# Gen 5: Best fitness = 0.1464, Spearman IC = 0.0499
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01f619d0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4ec87ec0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefeb9b0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefebb00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefe9e20>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefeaa80>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefebb90>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefe8b60>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefe9550>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefe9d60>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6edfefe8fe0>)]
# Gen 6: Best fitness = 0.1464, Spearman IC = 0.0499
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01fc2480>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01f632f0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee012a2420>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee012a0740>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee012a1280>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee012a2c00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee012a1430>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee012a29c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee012a3200>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ee012a1580>), ((-inf, 0), <__main__.AlphaNode object at 0xf6ee012a15b0>)]
# Gen 7: Best fitness = 0.1464, Spearman IC = 0.0499
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4ec87fe0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4ec87b60>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e083ce0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e0839b0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e0802c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e083e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e083b90>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e083110>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e083d40>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e083c80>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e083170>)]
# Gen 8: Best fitness = 0.1464, Spearman IC = 0.0499
# /tmp/ipykernel_3800/349403202.py:23: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   spearman_corr, _ = spearmanr(x, y)
# [((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e67e00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01e65340>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e9120c0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e913cb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee01fc2570>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e080140>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e082e40>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e083b00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ed4e082f00>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee0128f6e0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee0128e600>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee0128edb0>), ((np.float32(0.14639929), np.float32(0.04992599)), <__main__.AlphaNode object at 0xf6ee0128f200>), ((np.float32(0.018533742), np.float32(0.0022170485)), <__main__.AlphaNode object at 0xf6ee0128d160>), ((np.float32(0.007927526), np.float32(0.00031892734)), <__main__.AlphaNode object at 0xf6ee0128e5a0>)]
# Gen 9: Best fitness = 0.1464, Spearman IC = 0.0499
# (np.float32(0.14639929), np.float32(0.04992599))

# %%
best_tree = max(final_scores, key=lambda x: x[0])

best_alpha = best_tree[1].get_formula()

print(best_alpha)
# Out:
# df['return']
